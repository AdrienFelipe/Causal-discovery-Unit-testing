# %%
import numpy as np
import random
import sys
from typing import Callable

# %load_ext autoreload
# %autoreload 2

sys.path.append('src')
from Generator import Generator
from History import History

# %% [markdown]
# Sample complexity
# Complejidad muestral

# %% [markdown]
# ## No time, no order

# %% [markdown]
# ### Instant action
# Observaciones independientes binarias/categorícas (determinista)
# dedes baesians
# https://github.com/pgmpy/pgmpy

# %%
random.seed(12)

event_function: Callable[[History], float] = lambda history: \
    1 if history.get_event() == 1 else 0

dataset = Generator() \
    .add_discrete() \
    .add_discrete() \
    .add_function(event_function)

display(dataset.generate().astype(int))

dataset.plot_relations()
# Out:
#    E1  E2  E3
# 0   1   0   1
# 1   1   1   1
# 2   0   0   0
# /opt/anaconda/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /opt/anaconda/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %% [markdown]
# ### Random samples
# Observaciones indepnedientes de variables continuas
# Exchangeable
#
# ruido gausiano
# https://en.wikipedia.org/wiki/Structural_equation_modeling

# %%
random.seed(10)

event_function: Callable[[History], float] = lambda history: \
    2 * history.get_event()

dataset = Generator() \
    .add_uniform() \
    .add_uniform() \
    .add_function(event_function)

display(dataset.generate().astype(int))

dataset.plot_relations()
# Out:
#    E1  E2  E3
# 0   5   8  11
# 1   5   2  10
# 2   8   3  17

# %% [markdown]
# ## With order, no time

# %% [markdown]
# ### Logs like

# %%
random.seed(1)

event_function: Callable[[History], float] = lambda history: \
    1 if history.get_event() == 1 else None

dataset = Generator(sequential=True) \
    .add_discrete() \
    .add_function(event_function) \
    .add_discrete()

display(dataset.generate())

dataset.plot_relations()
# Out:
#     E1   E2   E3
# 0  1.0  NaN  NaN
# 1  NaN  1.0  NaN
# 2  NaN  NaN  1.0

# %% [markdown]
# ### Sensors reads
# Lectura secuencial de sensores

# %%
random.seed(14)

event_function: Callable[[History], float] = lambda history: \
    2 * history.get_event(delay=1) + 3

dataset = Generator(sequential=True) \
    .add_uniform(round=0) \
    .add_uniform(round=0) \
    .add_function(event_function, round=0)

display(dataset.generate())

dataset.plot_relations()
# Out:
#     E1   E2    E3
# 0  7.0  NaN   NaN
# 1  NaN  3.0   NaN
# 2  NaN  NaN  17.0

# %% [markdown]
# ## With time
# ### Pattern search
# uniform sample
# muestreos con tiempos uniformes
#
# tidybench (causali discovery from time series)
# tigramite (causal discovery from time series)

# %%
event_function: Callable[[History], float] = lambda history: \
    np.sin(history.get_timestamp() / 60 / 5 * np.pi / 2)

dataset = Generator() \
    .add_function(event_function) \
    .set_time('2018-05-13 20:15', step='5m')

display(dataset.generate(6).astype(int))

dataset.plot_relations()
# Out:
#    E1           T
# 0  -1  1526235300
# 1   0  1526235600
# 2   1  1526235900
# 3   0  1526236200
# 4  -1  1526236500
# 5   0  1526236800

# %% [markdown]
# #### Date noise

# %%
random.seed(1)

event_function: Callable[[History], float] = lambda history: \
    np.sin(history.get_timestamp() / 60 / 60 * np.pi / 2)

dataset = Generator() \
    .add_function(event_function) \
    .set_time('2010-10-20 20:00', step='1h', precision='10m')

display(dataset.generate(6).round(1))

dataset.plot_relations()
# Out:
#     E1             T
# 0 -0.2  1.287598e+09
# 1 -1.0  1.287601e+09
# 2  0.2  1.287605e+09
# 3  1.0  1.287609e+09
# 4  0.3  1.287611e+09
# 5 -1.0  1.287615e+09

# %% [markdown]
# ## With delay

# %%
random.seed(5)

event_function: Callable[[History], float] = lambda history: \
    2 * history.get_event(delay=2, null_value=0)

dataset = Generator() \
    .add_uniform(1, 3, round=0) \
    .add_function(event_function, round=0)

display(dataset.generate(6).astype(int))

dataset.plot_relations()
# Out:
#    E1  E2
# 0   3   0
# 1   1   0
# 2   3   6
# 3   2   2
# 4   2   6
# 5   3   4

# %% [markdown]
# ## Multiple causes

# %%
random.seed(10)

event_function: Callable[[History], float] = lambda history: \
    history.get_event(1) + history.get_event(2)

dataset = Generator() \
    .add_uniform() \
    .add_uniform() \
    .add_function(event_function)

display(dataset.generate().astype(int))

dataset.plot_relations()
# Out:
#    E1  E2  E3
# 0   5   8  13
# 1   5   2   7
# 2   8   3  12

# %% [markdown]
# tipo de ruido
# gausiano / exponencial / no gausiano

# %% [markdown]
# ## Shadow causes

# %%
random.seed(10)

event_function: Callable[[History], float] = lambda history: \
    history.get_event(1) + history.get_event(2)

dataset = Generator() \
    .add_uniform(shadow=True) \
    .add_uniform() \
    .add_function(event_function)

display(dataset.generate().astype(int))


dataset.plot_relations()
# Out:
#    E2  E3
# 0   8  13
# 1   2   7
# 2   3  12

# %% [markdown]
# ## Multiple effects

# %%
random.seed(3)

dataset = Generator() \
    .add_uniform() \
    .add_function(lambda history: int(history.get_event()) * 2) \
    .add_function(lambda history: history.get_event() + 1)

display(dataset.generate().astype(int))

dataset.plot_relations()
# Out:
#    E1  E2  E3
# 0   3   6   4
# 1   8  16   9
# 2   8  16   9

# %% [markdown]
# # Sales history dataset

# %%
def week_day(history: History) -> float:
    day = history.get_datetime().weekday()
    ratios = [20, 20, 15, 5, 0, -20, -30]
    return 1 + ratios[day] / 100

def sales(history: History) -> float:
    return history.get_event(1) * history.get_event(2)

# %%
dataset = Generator() \
    .set_time('2020-02-20', step='1d') \
    .add_constant(300, shadow=True) \
    .add_function(week_day, shadow=True) \
    .add_function(sales)

dataset.plot_relations()
dataset.generate(50).plot(x='T', y='E3', figsize=(16.5,2))

# %%
dataset = Generator() \
    .set_time('2020-02-20', step='1d') \
    .add_uniform(250, 300, shadow=True) \
    .add_function(week_day, shadow=True) \
    .add_function(sales)

dataset.plot_relations(fig_size=(6, 3))
dataset.generate(50).plot(x='T', y='E3', figsize=(16.5,2))

# %%
def year_week(history: History) -> float:
    week = history.get_datetime().isocalendar()[1]
    ratio = week - history.get_datetime(-1).isocalendar()[1]
    return 1 + ratio / 5

# %%
dataset = Generator() \
    .set_time('2020-02-20', step='1d') \
    .add_uniform(250, 300, shadow=True) \
    .add_function(week_day, shadow=True) \
    .add_function(year_week, shadow=True) \
    .add_function(lambda h: h.get_event(1) * h.get_event(2) * h.get_event(3))

dataset.plot_relations(fig_size=(7,3))
dataset.generate(50).plot(x='T', y='E4', figsize=(16.5,2))

# %%
def promo(history: History) -> float:
    value = 0
    if history.get_event(4, delay=1):
        value = 500 + random.uniform(-100, 100)
    if history.get_event(4, delay=2):
        value = 400 + random.uniform(-100, 100)
    if history.get_event(4, delay=3):
        value = 200 + random.uniform(-50, 50)

    return value

# %%
random.seed(2)

dataset = Generator() \
    .set_time('2020-02-20', step='1d', label='Date') \
    .add_uniform(250, 300, shadow=True, label='Base\nsales') \
    .add_function(week_day, shadow=True, label='Week\nday') \
    .add_function(year_week, shadow=True, label='Year\nweek') \
    .add_discrete(0.05, label='Promo\nlaunch') \
    .add_function(promo, shadow=True, label='Promo\ndelay') \
    .add_function(lambda h: h.get_event(1) * h.get_event(2) * h.get_event(3) + h.get_event(5), round=0, label='Sales')

dataset.plot_relations(fig_size=(13,7), node_size=45)
dataframe = dataset.generate(50)
display(dataframe.head())

time_label=dataset.get_events()[0].label
data_label=dataset.get_events()[6].label
dataframe.plot(x=time_label, y=data_label, figsize=(16.5,2))
# Out:
#            Date  Promo launch  Sales
# 0  1.582153e+09           0.0  265.0
# 1  1.582240e+09           1.0  258.0
# 2  1.582326e+09           0.0  707.0
# 3  1.582412e+09           0.0  665.0
# 4  1.582499e+09           1.0  640.0

# %% [markdown]
# # Gene expression dataset

# %%
def pathology(history: History) -> float:
    gene1 = history.get_event(1) > 0.8
    gene2 = history.get_event(2) > 0.7
    gene5 = history.get_event(5) > 0.6

    return gene1 and gene2 or gene5

# %%
import seaborn as sns

dataset = Generator() \
    .add_uniform(0, 1) \
    .add_uniform(0, 1, shadow=True) \
    .add_uniform(0, 1) \
    .add_uniform(0, 1) \
    .add_function(lambda h: (h.e(3) + h.e(4))/2) \
    .add_uniform(0, 1) \
    .add_uniform(0, 1) \
    .add_function(pathology, label='P')

dataset.plot_relations(fig_size=(10,4))

cmap = sns.diverging_palette(11, 135, s=99, n=10, center="dark")
sns.heatmap(dataset.generate(50), cmap=cmap)

# %% [markdown]
# # Logs dataset

# %%
import pandas as pd
random.seed(9)

def server_down(h: History) -> float:
    try:
        load_log = h.get_range(position=1, time_range='1m', null_value=0)
        high_load = max(load_log) > 90 if len(load_log) is not 0 else None
        
        error_log = h.get_range(position=2, time_range='2m')
        critical = any(error_log=='critical')
        warning = any(error_log=='warning')
        
        print('------')
        print('load_log', load_log)
        print('high_load', high_load, '<--')
        print('error_log', error_log)
        print('critical', critical, '<--')
        print('warning', warning, '<--')
        print('result', 'server down' if critical or (warning and high_load) else None)
        print('------')
        
        return 'server down' if critical or (warning and high_load) else None
    except Exception as err:
        print('error:', err)
    
dataset = Generator(sequential=True) \
    .set_time(step='10s', precision='10s') \
    .add_uniform(70, 100, probability=0.4, round=0, label='System\nhigh load') \
    .add_categorical(['notice', 'warning', 'critical'], probability=0.2, label='System\nfault') \
    .add_function(server_down, probability=0.9, label='Server\ndown')
    
    
dataset.plot_relations(node_size=50, fig_size=(10,4))
dataframe = dataset.generate(100)
dataframe['T'] = pd.to_datetime(dataframe['T'].round(0), unit='s')
display(dataframe.head(30))
scatter = dataframe.set_index('T').stack().reset_index(name='value').rename(columns={'level_1':'type'})
scatter[scatter['value'] > 0].plot.scatter(x='T', y='value', s=100)
# Out:
# ------
# load_log [96.0]
# high_load True <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [92.0 0]
# high_load True <--
# error_log [None 'notice' None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [94.0 92.0]
# high_load True <--
# error_log [None None 'notice' None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0 94.0]
# high_load True <--
# error_log ['warning' None None 'notice']
# critical False <--
# warning True <--
# result server down
# ------
# ------
# load_log [73.0 0 0]
# high_load False <--
# error_log [None None 'warning' None None]
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [73.0 0]
# high_load False <--
# error_log [None None 'warning' None]
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [91.0]
# high_load True <--
# error_log [None None None 'warning']
# critical False <--
# warning True <--
# result server down
# ------
# ------
# load_log [80.0 0 91.0]
# high_load True <--
# error_log [None None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [83.0 80.0]
# high_load False <--
# error_log [None None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [83.0]
# high_load False <--
# error_log [None None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log ['warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [100.0]
# high_load True <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [92.0 100.0]
# high_load True <--
# error_log [None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [96.0 92.0]
# high_load True <--
# error_log [None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0 96.0]
# high_load True <--
# error_log ['warning' None None None]
# critical False <--
# warning True <--
# result server down
# ------
# ------
# load_log [77.0 0]
# high_load False <--
# error_log [None 'critical' None None 'warning']
# critical True <--
# warning True <--
# result server down
# ------
# ------
# load_log [0 0]
# high_load False <--
# error_log ['critical' None None 'critical' None]
# critical True <--
# warning False <--
# result server down
# ------
# ------
# load_log [78.0]
# high_load False <--
# error_log [None None 'critical' None]
# critical True <--
# warning False <--
# result server down
# ------
# ------
# load_log [78.0 0]
# high_load False <--
# error_log [None None None None 'critical' None]
# critical True <--
# warning False <--
# result server down
# ------
# ------
# load_log [0 78.0]
# high_load False <--
# error_log [None None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0 98.0]
# high_load True <--
# error_log ['notice' None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0 98.0]
# high_load True <--
# error_log ['notice' None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log ['notice' None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log ['notice' None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['notice']
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['notice']
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log ['notice']
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log ['notice']
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log []
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0 75.0]
# high_load False <--
# error_log ['critical' None]
# critical True <--
# warning False <--
# result server down
# ------
# ------
# load_log [81.0 0 0 75.0]
# high_load False <--
# error_log [None None 'critical' None]
# critical True <--
# warning False <--
# result server down
# ------
# ------
# load_log [0 81.0 0]
# high_load False <--
# error_log [None None None 'critical' None]
# critical True <--
# warning False <--
# result server down
# ------
# ------
# load_log [0]
# high_load False <--
# error_log [None None None None 'critical' None]
# critical True <--
# warning False <--
# result server down
# ------
# ------
# load_log [89.0 0]
# high_load False <--
# error_log [None None None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [71.0 89.0]
# high_load False <--
# error_log [None None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [71.0]
# high_load False <--
# error_log [None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [85.0]
# high_load False <--
# error_log [None None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [85.0]
# high_load False <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['warning' None]
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [98.0 0]
# high_load True <--
# error_log [None 'warning' None]
# critical False <--
# warning True <--
# result server down
# ------
# ------
# load_log [0]
# high_load False <--
# error_log [None None 'warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None None 'warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [70.0 0]
# high_load False <--
# error_log [None 'notice' 'warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [70.0]
# high_load False <--
# error_log [None 'notice' 'warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [0 94.0]
# high_load True <--
# error_log ['warning' None None 'notice']
# critical False <--
# warning True <--
# result server down
# ------
# ------
# load_log [0 0 0 94.0]
# high_load True <--
# error_log ['critical' None 'warning' None None]
# critical True <--
# warning True <--
# result server down
# ------
# ------
# load_log [0 0 0]
# high_load False <--
# error_log [None 'critical' None 'warning' None]
# critical True <--
# warning True <--
# result server down
# ------
# ------
# load_log [91.0 0]
# high_load True <--
# error_log [None None None 'critical' None 'warning' None]
# critical True <--
# warning True <--
# result server down
# ------
# ------
# load_log [0 91.0 0]
# high_load True <--
# error_log [None None None None 'critical' None 'warning']
# critical True <--
# warning True <--
# result server down
# ------
# ------
# load_log [0 0]
# high_load False <--
# error_log [None None None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['critical']
# critical True <--
# warning False <--
# result server down
# ------
# ------
# load_log [0 0]
# high_load False <--
# error_log [None 'critical']
# critical True <--
# warning False <--
# result server down
# ------
# ------
# load_log [81.0 0 0]
# high_load False <--
# error_log [None None None 'critical']
# critical True <--
# warning False <--
# result server down
# ------
# ------
# load_log [0 81.0]
# high_load False <--
# error_log [None None None None 'critical']
# critical True <--
# warning False <--
# result server down
# ------
# ------
# load_log [82.0 0]
# high_load False <--
# error_log [None None None None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [95.0]
# high_load True <--
# error_log [None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [71.0]
# high_load False <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [83.0]
# high_load False <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0 78.0]
# high_load False <--
# error_log ['notice' None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['notice' None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0 72.0]
# high_load False <--
# error_log ['warning' None 'notice']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['warning' 'warning' None]
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['warning' 'warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [83.0]
# high_load False <--
# error_log [None 'warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [72.0 83.0]
# high_load False <--
# error_log [None None 'warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [72.0]
# high_load False <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [72.0]
# high_load False <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0 79.0 72.0]
# high_load False <--
# error_log ['notice' None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0 79.0]
# high_load False <--
# error_log ['notice' None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['warning' 'notice' None None]
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [72.0 0]
# high_load False <--
# error_log [None 'warning' 'notice' None]
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [0 72.0]
# high_load False <--
# error_log ['notice' None 'warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['notice' None 'warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [92.0]
# high_load True <--
# error_log [None 'notice']
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [90.0 92.0]
# high_load True <--
# error_log [None None 'notice']
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [81.0]
# high_load False <--
# error_log [None None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [81.0]
# high_load False <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [76.0]
# high_load False <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [76.0]
# high_load False <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log []
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log []
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log ['warning']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log []
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [71.0]
# high_load False <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [71.0]
# high_load False <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log []
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [85.0]
# high_load False <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log []
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [90.0]
# high_load False <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [87.0 90.0]
# high_load False <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [87.0]
# high_load False <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['notice' None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [96.0 0]
# high_load True <--
# error_log [None 'notice' None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0 78.0 96.0 0]
# high_load True <--
# error_log ['notice' None None 'notice']
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0]
# high_load False <--
# error_log ['notice' None None 'notice']
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [0 83.0 0]
# high_load False <--
# error_log ['warning' None 'notice' None None 'notice']
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [87.0 0 83.0]
# high_load False <--
# error_log [None 'warning' None 'notice' None]
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [81.0 87.0]
# high_load False <--
# error_log [None None 'warning' None]
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log [81.0]
# high_load False <--
# error_log [None None 'warning' None]
# critical False <--
# warning True <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [93.0]
# high_load True <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [86.0]
# high_load False <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [86.0]
# high_load False <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [70.0]
# high_load False <--
# error_log [None None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log [70.0]
# high_load False <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log [None]
# critical False <--
# warning False <--
# result None
# ------
# ------
# load_log []
# high_load None <--
# error_log []
# critical False <--
# warning False <--
# result None
# ------
#     Server down System fault System high load                   T
# 0           NaN          NaN               96 2020-04-22 11:25:54
# 1          None       notice             None 2020-04-22 11:26:41
# 2           NaN          NaN               92 2020-04-22 11:27:02
# 3           NaN          NaN               94 2020-04-22 11:27:21
# 4          None      warning             None 2020-04-22 11:28:09
# 5   server down         None             None 2020-04-22 11:28:11
# 6           NaN          NaN               73 2020-04-22 11:28:28
# 7           NaN          NaN               91 2020-04-22 11:29:37
# 8   server down         None             None 2020-04-22 11:29:44
# 9           NaN          NaN               80 2020-04-22 11:30:02
# 10          NaN          NaN               83 2020-04-22 11:30:33
# 11         None      warning             None 2020-04-22 11:32:34
# 12          NaN          NaN               75 2020-04-22 11:33:51
# 13          NaN          NaN              100 2020-04-22 11:34:36
# 14          NaN          NaN               92 2020-04-22 11:34:58
# 15          NaN          NaN               96 2020-04-22 11:35:29
# 16         None      warning             None 2020-04-22 11:35:58
# 17  server down         None             None 2020-04-22 11:36:08
# 18          NaN          NaN               93 2020-04-22 11:36:28
# 19         None     critical             None 2020-04-22 11:36:42
# 20          NaN          NaN               77 2020-04-22 11:36:49
# 21  server down         None             None 2020-04-22 11:37:42
# 22         None     critical             None 2020-04-22 11:37:57
# 23  server down         None             None 2020-04-22 11:38:12
# 24          NaN          NaN               78 2020-04-22 11:38:21
# 25  server down         None             None 2020-04-22 11:39:17
# 26          NaN          NaN               78 2020-04-22 11:39:25
# 27  server down         None             None 2020-04-22 11:39:41
# 28          NaN          NaN               98 2020-04-22 11:41:18
# 29         None       notice             None 2020-04-22 11:41:30
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-169-847b30e5732d> in <module>
#      36 display(dataframe.head(30))
#      37 scatter = dataframe.set_index('T').stack().reset_index(name='value').rename(columns={'level_1':'type'})
# ---> 38 scatter[scatter['value'] > 0].plot.scatter(x='T', y='value', s=100)
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1089
#    1090         if is_object_dtype(x.dtype):
# -> 1091             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1092
#    1093         elif is_datetimelike_v_numeric(x, y):
#
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/ops/__init__.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1067         result = libops.vec_compare(x, y, op)
#    1068     else:
# -> 1069         result = libops.scalar_compare(x, y, op)
#    1070     return result
#    1071
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
import numpy as np
from collections import deque

position = 3
time_limit = 1
null_value = 0

events=deque()
events.appendleft([1,1,1,1])
events.appendleft([2,1,None,1])
events.appendleft([3,1,1,None])
events.appendleft([4,1,1,None])

np_events = np.array(events)
result = np_events[:, position][np_events[:, 0] > time_limit]
if null_value is not None:
    result = np.where(result == None, null_value, result)

display(result)
# Out:
# array([0, 0, 1], dtype=object)
