# %%
import numpy as np
import random
import sys
from typing import Callable

# %load_ext autoreload
# %autoreload 2

sys.path.append('src')
from Generator import Generator
from History import History
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Sample complexity
# Complejidad muestral

# %% [markdown]
# ## No time, no order

# %% [markdown]
# ### Instant action
# Observaciones independientes binarias/categorícas (determinista)
# dedes baesians
# https://github.com/pgmpy/pgmpy

# %%
random.seed(12)

event_function: Callable[[History], float] = lambda history: \
    1 if history.get_event() == 1 else 0

dataset = Generator() \
    .add_discrete() \
    .add_discrete() \
    .add_function(event_function)

display(dataset.generate().astype(int))

dataset.plot_relations()
# Out:
#    E1  E2  E3
# 0   1   0   1
# 1   1   1   1
# 2   0   0   0

# %% [markdown]
# ### Random samples
# Observaciones indepnedientes de variables continuas
# Exchangeable
#
# ruido gausiano
# https://en.wikipedia.org/wiki/Structural_equation_modeling

# %%
random.seed(10)

event_function: Callable[[History], float] = lambda history: \
    2 * history.get_event()

dataset = Generator() \
    .add_continuous() \
    .add_continuous() \
    .add_function(event_function)

display(dataset.generate().astype(int))

dataset.plot_relations()
# Out:
#    E1  E2  E3
# 0   5   8  11
# 1   5   2  10
# 2   8   3  17

# %% [markdown]
# ## With order, no time

# %% [markdown]
# ### Logs like

# %%
random.seed(1)

event_function: Callable[[History], float] = lambda history: \
    1 if history.get_event() == 1 else None

dataset = Generator(sequential=True) \
    .add_discrete() \
    .add_function(event_function) \
    .add_discrete()

display(dataset.generate())

dataset.plot_relations()
# Out:
#     E1   E2   E3
# 0  1.0  NaN  NaN
# 1  NaN  1.0  NaN
# 2  NaN  NaN  1.0

# %% [markdown]
# ### Sensors reads
# Lectura secuencial de sensores

# %%
random.seed(14)

event_function: Callable[[History], float] = lambda history: \
    2 * history.get_event(delay=1) + 3

dataset = Generator(sequential=True) \
    .add_continuous(round=0) \
    .add_continuous(round=0) \
    .add_function(event_function, round=0)

display(dataset.generate())

dataset.plot_relations()
# Out:
#     E1   E2    E3
# 0  7.0  NaN   NaN
# 1  NaN  3.0   NaN
# 2  NaN  NaN  17.0

# %% [markdown]
# ## With time
# ### Pattern search
# uniform sample
# muestreos con tiempos uniformes
#
# tidybench (causali discovery from time series)
# tigramite (causal discovery from time series)

# %%
event_function: Callable[[History], float] = lambda history: \
    np.sin(history.get_timestamp() / 60 / 5 * np.pi / 2)

dataset = Generator() \
    .add_function(event_function) \
    .set_time('2018-05-13 20:15', step='5m')

display(dataset.generate(6).astype(int))

dataset.plot_relations()
# Out:
#    E1           T
# 0  -1  1526235300
# 1   0  1526235600
# 2   1  1526235900
# 3   0  1526236200
# 4  -1  1526236500
# 5   0  1526236800

# %% [markdown]
# #### Date noise

# %%
random.seed(1)

event_function: Callable[[History], float] = lambda history: \
    np.sin(history.get_timestamp() / 60 / 60 * np.pi / 2)

dataset = Generator() \
    .add_function(event_function) \
    .set_time('2010-10-20 20:00', step='1h', precision='10m')

display(dataset.generate(6).round(1))

dataset.plot_relations()
# Out:
#     E1             T
# 0 -0.2  1.287598e+09
# 1 -1.0  1.287601e+09
# 2  0.2  1.287605e+09
# 3  1.0  1.287609e+09
# 4  0.3  1.287611e+09
# 5 -1.0  1.287615e+09

# %% [markdown]
# ## With delay

# %%
random.seed(5)

event_function: Callable[[History], float] = lambda history: \
    2 * history.get_event(delay=2, null_value=0)

dataset = Generator() \
    .add_continuous(1, 3, round=0) \
    .add_function(event_function, round=0)

display(dataset.generate(6).astype(int))

dataset.plot_relations()
# Out:
#    E1  E2
# 0   3   0
# 1   1   0
# 2   3   6
# 3   2   2
# 4   2   6
# 5   3   4

# %% [markdown]
# ## Multiple causes

# %%
random.seed(10)

event_function: Callable[[History], float] = lambda history: \
    history.get_event(1) + history.get_event(2)

dataset = Generator() \
    .add_continuous() \
    .add_continuous() \
    .add_function(event_function)

display(dataset.generate().astype(int))

dataset.plot_relations()
# Out:
#    E1  E2  E3
# 0   5   8  13
# 1   5   2   7
# 2   8   3  12

# %% [markdown]
# tipo de ruido
# gausiano / exponencial / no gausiano

# %% [markdown]
# ## Shadow causes

# %%
random.seed(10)

event_function: Callable[[History], float] = lambda history: \
    history.get_event(1) + history.get_event(2)

dataset = Generator() \
    .add_continuous(shadow=True) \
    .add_continuous() \
    .add_function(event_function)

display(dataset.generate().astype(int))


dataset.plot_relations()
# Out:
#    E2  E3
# 0   8  13
# 1   2   7
# 2   3  12

# %% [markdown]
# ## Multiple effects

# %%
random.seed(3)

dataset = Generator() \
    .add_continuous() \
    .add_function(lambda history: int(history.get_event()) * 2) \
    .add_function(lambda history: history.get_event() + 1)

display(dataset.generate().astype(int))

dataset.plot_relations()
# Out:
#    E1  E2  E3
# 0   3   6   4
# 1   8  16   9
# 2   8  16   9

# %% [markdown]
# # Sales history dataset

# %%
def week_day(history: History) -> float:
    day = history.get_datetime().weekday()
    ratios = [20, 20, 15, 5, 0, -20, -30]
    return 1 + ratios[day] / 100

def sales(history: History) -> float:
    return history.get_event(1) * history.get_event(2)

# %%
dataset = Generator() \
    .set_time('2020-02-20', step='1d') \
    .add_constant(300, shadow=True) \
    .add_function(week_day, shadow=True) \
    .add_function(sales)

dataset.plot_relations()
dataset.generate(50).plot(x='T', y='E3', figsize=(16.5,2))

# %%
dataset = Generator() \
    .set_time('2020-02-20', step='1d') \
    .add_continuous(250, 300, shadow=True) \
    .add_function(week_day, shadow=True) \
    .add_function(sales)

dataset.plot_relations(fig_size=(6, 3))
dataset.generate(50).plot(x='T', y='E3', figsize=(16.5,2))

# %%
def year_week(history: History) -> float:
    week = history.get_datetime().isocalendar()[1]
    ratio = week - history.get_datetime(-1).isocalendar()[1]
    return 1 + ratio / 5

# %%
dataset = Generator() \
    .set_time('2020-02-20', step='1d') \
    .add_continuous(250, 300, shadow=True) \
    .add_function(week_day, shadow=True) \
    .add_function(year_week, shadow=True) \
    .add_function(lambda h: h.get_event(1) * h.get_event(2) * h.get_event(3))

dataset.plot_relations(fig_size=(7,3))
dataset.generate(50).plot(x='T', y='E4', figsize=(16.5,2))

# %%
def promo(history: History) -> float:
    value = 0
    if history.get_event(4, delay=1):
        value = 500 + random.uniform(-100, 100)
    if history.get_event(4, delay=2):
        value = 400 + random.uniform(-100, 100)
    if history.get_event(4, delay=3):
        value = 200 + random.uniform(-50, 50)

    return value

# %%
random.seed(2)

dataset = Generator() \
    .set_time('2020-02-20', step='1d', name='Date') \
    .add_continuous(250, 300, shadow=True, name='Base\nsales') \
    .add_function(week_day, shadow=True, name='Week\nday') \
    .add_function(year_week, shadow=True, name='Year\nweek') \
    .add_discrete(0.05, name='Promo\nlaunch') \
    .add_function(promo, shadow=True, name='Promo\nimpact') \
    .add_function(lambda h: h.get_event(1) * h.get_event(2) * h.get_event(3) + h.get_event(5), round=0, name='Sales')

dataset.plot_relations(fig_size=(13,7), node_size=45)
dataframe = dataset.generate(50)
display(dataframe.head())
dataframe.plot(x=dataset.get_events()[0].label, y=dataset.get_events()[6].label, figsize=(16.5,2))
# Out:
#            Date  Promo\nlaunch  Sales
# 0  1.582153e+09            0.0  265.0
# 1  1.582240e+09            1.0  258.0
# 2  1.582326e+09            0.0  707.0
# 3  1.582412e+09            0.0  665.0
# 4  1.582499e+09            1.0  640.0

# %% [markdown]
# # Gene expression dataset

# %%
def pathology(history: History) -> float:
    gene1 = history.get_event(1) > 0.8
    gene2 = history.get_event(2) > 0.7
    gene5 = history.get_event(5) > 0.6

    return gene1 and gene2 or gene5

# %%
import seaborn as sns

dataset = Generator() \
    .add_continuous(0, 1) \
    .add_continuous(0, 1) \
    .add_continuous(0, 1) \
    .add_continuous(0, 1) \
    .add_function(lambda h: (h.get_event(3) + h.get_event(4))/2) \
    .add_continuous(0, 1) \
    .add_continuous(0, 1) \
    .add_function(pathology, name='P')

dataset.plot_relations(fig_size=(10,4))

cmap = sns.diverging_palette(11, 135, s=99, n=10, center="dark")
sns.heatmap(dataset.generate(50), cmap=cmap)

# %% [markdown]
# # Logs dataset

# %%
random.seed(9)
dataset = Generator(sequential=True) \
    .set_time(step='30s', precision='30s') \
    .add_continuous(0, 100, name='System\nload') \
    .add_discrete(0.1, probability=0.8, name='System\nfault') \
    .add_function(lambda h: h.get_event(1), name='Server\ndown')
    
dataset.plot_relations(node_size=30)
scatter = dataset.generate(100).set_index('T').stack().reset_index(name='value').rename(columns={'level_1':'type'})
scatter[scatter['value'] > 0].plot.scatter(x='T', y='value', s=100)
