# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%javascript
# // Disable cell scrolling.
# IPython.OutputArea.auto_scroll_threshold = 99999;

# %%
from discovery.EvaluateLearner import EvaluateLearner
from ui.config import scripts, datasets

EvaluateLearner.run(scripts, datasets, output=EvaluateLearner.GRAPH_OUTPUT)
# Out:
# Direct Causality - Linear → PC (pgmpy): 0%
# Direct Causality - Linear → greedy (pyAgrum): 0%
# Direct Causality - Square root → PC (pgmpy): 0%
# Direct Causality - Square root → greedy (pyAgrum): 0%
# Direct Causality - Power → PC (pgmpy): 0%
# Direct Causality - Power → greedy (pyAgrum): 25%
# Direct Causality - Exponential → PC (pgmpy): 0%
# Direct Causality - Exponential → greedy (pyAgrum): 0%
# Multiple Causes - Linear → PC (pgmpy): 0%
# Multiple Causes - Linear → greedy (pyAgrum): 25%
# Multiple Causes - Power → PC (pgmpy): 0%
# Multiple Causes - Power → greedy (pyAgrum): 25%
# Multiple Effects - Linear → PC (pgmpy): 0%
# Multiple Effects - Linear → greedy (pyAgrum): 19%
# Multiple Effects - Power → PC (pgmpy): 0%
# Multiple Effects - Power → greedy (pyAgrum): 19%
# Chained Causality - Linear → PC (pgmpy): 0%
# Chained Causality - Linear → greedy (pyAgrum): 0%
# 1
