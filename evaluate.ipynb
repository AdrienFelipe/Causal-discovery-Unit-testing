# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%javascript
# // Disable cell scrolling.
# IPython.OutputArea.auto_scroll_threshold = 99999;

# %%
from discovery.EvaluateLearner import EvaluateLearner
from ui.config import scripts, datasets

EvaluateLearner.run(scripts, datasets, output='graph')
# Out:
# Categorical Causality - Conditional → PC (pgmpy): 100%
# Categorical Causality - Conditional → Local search (pgmpy): 0%
# Categorical Causality - Conditional → greedy (pyAgrum): 100%
# 1
