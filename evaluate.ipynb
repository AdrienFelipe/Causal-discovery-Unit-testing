# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%javascript
# // Disable cell scrolling.
# IPython.OutputArea.auto_scroll_threshold = 99999;

# %%
from discovery.EvaluateLearner import EvaluateLearner
from ui.config import scripts, datasets

EvaluateLearner.run(scripts, datasets, output='graph')
# Out:
# Sales - Marketing campaigns → PC (pgmpy): 0%
# Sales - Marketing campaigns → Local search (pgmpy): 0%
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-6ec272894697> in <module>
#       2 from ui.config import scripts, datasets
#       3
# ----> 4 EvaluateLearner.run(scripts, datasets, output='graph')
#
# ~/src/discovery/EvaluateLearner.py in run(scripts, datasets, threshold, output, force_rebuild)
#      39                 ori_learned = script.predict(dataset)
#      40                 time = (datetime.datetime.now() - time).total_seconds()
# ---> 41                 learned = EvaluateLearner.relations_to_label(ori_learned, generator.get_events(include_shadow=False))
#      42
#      43                 real = EvaluateLearner.relations_to_label(generator.build_relations(), generator.get_events())
#
# ~/src/discovery/EvaluateLearner.py in relations_to_label(relations, events)
#      94         for relation in relations:
#      95             labeled_relations.append(
# ---> 96                 Relation(events[relation.source].label, events[relation.target].label, relation.delay))
#      97
#      98         return labeled_relations
#
# IndexError: list index out of range
