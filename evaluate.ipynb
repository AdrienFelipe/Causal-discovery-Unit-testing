# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%javascript
# // Disable cell scrolling.
# IPython.OutputArea.auto_scroll_threshold = 99999;

# %%
from discovery.EvaluateLearner import EvaluateLearner
from ui.config import scripts, datasets

EvaluateLearner.run(scripts, datasets, output='graph')
# Out:
# Multiple Causes - Discrete → PC (Pgmpy): 100%
# Multiple Causes - Discrete → GES (Pgmpy): 0%
# Multiple Causes - Discrete → GES (pyAgrum): 0%
# Multiple Causes - Discrete → TS (pyAgrum): 0%
# Direct Causality - Linear → PC (Pgmpy): 0%
# Direct Causality - Linear → GES (Pgmpy): 100%
# Direct Causality - Linear → GES (pyAgrum): 100%
# Direct Causality - Linear → TS (pyAgrum): 100%
# Chained Causality - Linear → PC (Pgmpy): 0%
# Chained Causality - Linear → GES (Pgmpy): 19%
# Chained Causality - Linear → GES (pyAgrum): 50%
# Chained Causality - Linear → TS (pyAgrum): 25%
# 1
