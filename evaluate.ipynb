# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%javascript
# // Disable cell scrolling.
# IPython.OutputArea.auto_scroll_threshold = 99999;

# %%
from discovery.EvaluateLearner import EvaluateLearner
from ui.config import scripts, datasets

EvaluateLearner.run(scripts, datasets, output='graph')
# Out:
# Relational Causality - Discrete → greedy (pyAgrum): 50%
# Relational Causality - Discrete → local search (pyAgrum): 100%
# Chained Causality - Linear → greedy (pyAgrum): 19%
# Chained Causality - Linear → local search (pyAgrum): 50%
# Direct Causality - Linear → greedy (pyAgrum): 0%
# Direct Causality - Linear → local search (pyAgrum): 33%
# Direct Causality - Square root → greedy (pyAgrum): 0%
# Direct Causality - Square root → local search (pyAgrum): 25%
# Direct Causality - Power → greedy (pyAgrum): 0%
# Direct Causality - Power → local search (pyAgrum): 25%
# Direct Causality - Exponential → greedy (pyAgrum): 0%
# Direct Causality - Exponential → local search (pyAgrum): 0%
# Multiple Causes - Linear → greedy (pyAgrum): 0%
# Multiple Causes - Linear → local search (pyAgrum): 50%
# Multiple Causes - Power → greedy (pyAgrum): 0%
# Multiple Causes - Power → local search (pyAgrum): 50%
# Multiple Effects - Linear → greedy (pyAgrum): 19%
# Multiple Effects - Linear → local search (pyAgrum): 40%
# Multiple Effects - Power → greedy (pyAgrum): 19%
# Multiple Effects - Power → local search (pyAgrum): 40%
# Chained Causality - Linear → greedy (pyAgrum): 19%
# Chained Causality - Linear → local search (pyAgrum): 50%
# 1
